# %%
print 'hello world'
# Out:
# hello world

# %% [markdown]
# ## Inisiasi client Twittter

# %% [raw]
# Berikan informasi akses Twitter dengan menspesifikasikan consumer key, consumer secret, oauth token dan oauth token secret yang bisa didapatkan dari laman https://apps.twitter.com/

# %%
import twitter
import json

# %%
CONSUMER_KEY = '0IXLLUAm10iqPClS4yHQTA'
CONSUMER_SECRET = 'aO4K3HgmtDzZ6Xt49TP158KWTSFyqIpML5uLA5fLI'
OAUTH_TOKEN = '86517090-g6ThyTJPcyV3MvfpMwf5taaNAfQ4SZXSHXzm5CnYs'
OAUTH_TOKEN_SECRET = '9umsnC8Jv2Ir305EAe3EdjZpVFZzT9O0bkIPDA8aXMMB6'

# %%
auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET, CONSUMER_KEY, CONSUMER_SECRET)

# %%
twitter_api = twitter.Twitter(auth=auth)

# %%
print twitter_api
# Out:
# <twitter.api.Twitter object at 0x7fb5f8178dd0>

# %% [markdown]
# ## Mendapatkan Trending Topic

# %% [raw]
# Spesifikasikan Where On Earth (WOE) ID dari tempat yang akan kita dapatkan trending topicnya

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977
ID_WOE_ID = 23424846

# %% [raw]
# Prefix ID dengan underscore. Kemudian masukkan trending topic dalam variabel dan cetak.

# %%
world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
id_trends = twitter_api.trends.place(_id=ID_WOE_ID)
#print world_trends
#print
print json.dumps(id_trends, indent=1)
# Out:
# [
#  {
#   "created_at": "2017-01-03T03:30:32Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23PerjuanganBelumSelesai",
#     "query": "%23PerjuanganBelumSelesai",
#     "tweet_volume": null,
#     "name": "#PerjuanganBelumSelesai",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MiWar",
#     "query": "%23MiWar",
#     "tweet_volume": null,
#     "name": "#MiWar",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HBD21TataChiBi",
#     "query": "%23HBD21TataChiBi",
#     "tweet_volume": null,
#     "name": "#HBD21TataChiBi",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Pertanian",
#     "query": "Pertanian",
#     "tweet_volume": null,
#     "name": "Pertanian",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PagiPagi",
#     "query": "%23PagiPagi",
#     "tweet_volume": null,
#     "name": "#PagiPagi",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Basuki+Tjahaja+Purnama%22",
#     "query": "%22Basuki+Tjahaja+Purnama%22",
#     "tweet_volume": null,
#     "name": "Basuki Tjahaja Purnama",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22GT+Karang+Tengah%22",
#     "query": "%22GT+Karang+Tengah%22",
#     "tweet_volume": null,
#     "name": "GT Karang Tengah",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=STNK",
#     "query": "STNK",
#     "tweet_volume": null,
#     "name": "STNK",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BALIHOP",
#     "query": "%23BALIHOP",
#     "tweet_volume": null,
#     "name": "#BALIHOP",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Pergi+Dari+Hatiku%22",
#     "query": "%22Pergi+Dari+Hatiku%22",
#     "tweet_volume": null,
#     "name": "Pergi Dari Hatiku",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Pondok+Indah%22",
#     "query": "%22Pondok+Indah%22",
#     "tweet_volume": null,
#     "name": "Pondok Indah",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22West+Ham%22",
#     "query": "%22West+Ham%22",
#     "tweet_volume": 145968,
#     "name": "West Ham",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Zahro+Express%22",
#     "query": "%22Zahro+Express%22",
#     "tweet_volume": 17494,
#     "name": "Zahro Express",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22De+Gea%22",
#     "query": "%22De+Gea%22",
#     "tweet_volume": 17238,
#     "name": "De Gea",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Mike+Dean%22",
#     "query": "%22Mike+Dean%22",
#     "tweet_volume": 160312,
#     "name": "Mike Dean",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Pak+Anies%22",
#     "query": "%22Pak+Anies%22",
#     "tweet_volume": null,
#     "name": "Pak Anies",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Lingard",
#     "query": "Lingard",
#     "tweet_volume": 27375,
#     "name": "Lingard",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Jones",
#     "query": "Jones",
#     "tweet_volume": 109361,
#     "name": "Jones",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Sherlock",
#     "query": "Sherlock",
#     "tweet_volume": 230832,
#     "name": "Sherlock",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Feghouli",
#     "query": "Feghouli",
#     "tweet_volume": 32928,
#     "name": "Feghouli",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Giroud",
#     "query": "Giroud",
#     "tweet_volume": 122980,
#     "name": "Giroud",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Sunderland+2-2+Liverpool%22",
#     "query": "%22Sunderland+2-2+Liverpool%22",
#     "tweet_volume": null,
#     "name": "Sunderland 2-2 Liverpool",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Happy+New+Year%22",
#     "query": "%22Happy+New+Year%22",
#     "tweet_volume": 959059,
#     "name": "Happy New Year",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Randolph",
#     "query": "Randolph",
#     "tweet_volume": null,
#     "name": "Randolph",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22AADC+2%22",
#     "query": "%22AADC+2%22",
#     "tweet_volume": null,
#     "name": "AADC 2",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PenjarakanAhok",
#     "query": "%23PenjarakanAhok",
#     "tweet_volume": null,
#     "name": "#PenjarakanAhok",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SRIWEDARI",
#     "query": "%23SRIWEDARI",
#     "tweet_volume": null,
#     "name": "#SRIWEDARI",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23JAKARTAMORNINGSHOW",
#     "query": "%23JAKARTAMORNINGSHOW",
#     "tweet_volume": null,
#     "name": "#JAKARTAMORNINGSHOW",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MorningZone",
#     "query": "%23MorningZone",
#     "tweet_volume": null,
#     "name": "#MorningZone",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23OZMATASAPI",
#     "query": "%23OZMATASAPI",
#     "tweet_volume": null,
#     "name": "#OZMATASAPI",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SemangatPagiSBY",
#     "query": "%23SemangatPagiSBY",
#     "tweet_volume": null,
#     "name": "#SemangatPagiSBY",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HaloSelebriti",
#     "query": "%23HaloSelebriti",
#     "tweet_volume": null,
#     "name": "#HaloSelebriti",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TurnBackHoax",
#     "query": "%23TurnBackHoax",
#     "tweet_volume": null,
#     "name": "#TurnBackHoax",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%2323rdChiChooDay",
#     "query": "%2323rdChiChooDay",
#     "tweet_volume": 197866,
#     "name": "#23rdChiChooDay",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BenjiDiGigitUlar",
#     "query": "%23BenjiDiGigitUlar",
#     "tweet_volume": null,
#     "name": "#BenjiDiGigitUlar",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AngelDonghyukDay",
#     "query": "%23AngelDonghyukDay",
#     "tweet_volume": 183817,
#     "name": "#AngelDonghyukDay",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NovelRememberUs",
#     "query": "%23NovelRememberUs",
#     "tweet_volume": null,
#     "name": "#NovelRememberUs",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23GGMU",
#     "query": "%23GGMU",
#     "tweet_volume": null,
#     "name": "#GGMU",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23YangAsikPilihAgusSylvi",
#     "query": "%23YangAsikPilihAgusSylvi",
#     "tweet_volume": null,
#     "name": "#YangAsikPilihAgusSylvi",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PestaFPLJanuari",
#     "query": "%23PestaFPLJanuari",
#     "tweet_volume": null,
#     "name": "#PestaFPLJanuari",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23WWE2",
#     "query": "%23WWE2",
#     "tweet_volume": null,
#     "name": "#WWE2",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AlfamartWish",
#     "query": "%23AlfamartWish",
#     "tweet_volume": null,
#     "name": "#AlfamartWish",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BaDja2017",
#     "query": "%23BaDja2017",
#     "tweet_volume": null,
#     "name": "#BaDja2017",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SUNLIV",
#     "query": "%23SUNLIV",
#     "tweet_volume": 32469,
#     "name": "#SUNLIV",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MUFC",
#     "query": "%23MUFC",
#     "tweet_volume": 178895,
#     "name": "#MUFC",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ResolusiAniesSandi",
#     "query": "%23ResolusiAniesSandi",
#     "tweet_volume": 11912,
#     "name": "#ResolusiAniesSandi",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BagMiWedd",
#     "query": "%23BagMiWedd",
#     "tweet_volume": null,
#     "name": "#BagMiWedd",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ARMYSelcaDay",
#     "query": "%23ARMYSelcaDay",
#     "tweet_volume": 132323,
#     "name": "#ARMYSelcaDay",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23WHPH",
#     "query": "%23WHPH",
#     "tweet_volume": null,
#     "name": "#WHPH",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HappySeolhyunDay",
#     "query": "%23HappySeolhyunDay",
#     "tweet_volume": 18299,
#     "name": "#HappySeolhyunDay",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2017-01-03T03:35:46Z",
#   "locations": [
#    {
#     "woeid": 23424846,
#     "name": "Indonesia"
#    }
#   ]
#  }
# ]

# %% [raw]
# Tampilkan nama trending topic untuk Indonesia

# %%
list_id_trends = id_trends[0]["trends"]
#print id_trends[0]['created_at']
for trend in list_id_trends :
    print trend['name']
    print
# Out:
# #PerjuanganBelumSelesai
#
# #MiWar
#
# #HBD21TataChiBi
#
# Pertanian
#
# #PagiPagi
#
# Basuki Tjahaja Purnama
#
# GT Karang Tengah
#
# STNK
#
# #BALIHOP
#
# Pergi Dari Hatiku
#
# Pondok Indah
#
# West Ham
#
# Zahro Express
#
# De Gea
#
# Mike Dean
#
# Pak Anies
#
# Lingard
#
# Jones
#
# Sherlock
#
# Feghouli
#
# Giroud
#
# Sunderland 2-2 Liverpool
#
# Happy New Year
#
# Randolph
#
# AADC 2
#
# #PenjarakanAhok
#
# #SRIWEDARI
#
# #JAKARTAMORNINGSHOW
#
# #MorningZone
#
# #OZMATASAPI
#
# #SemangatPagiSBY
#
# #HaloSelebriti
#
# #TurnBackHoax
#
# #23rdChiChooDay
#
# #BenjiDiGigitUlar
#
# #AngelDonghyukDay
#
# #NovelRememberUs
#
# #GGMU
#
# #YangAsikPilihAgusSylvi
#
# #PestaFPLJanuari
#
# #WWE2
#
# #AlfamartWish
#
# #BaDja2017
#
# #SUNLIV
#
# #MUFC
#
# #ResolusiAniesSandi
#
# #BagMiWedd
#
# #ARMYSelcaDay
#
# #WHPH
#
# #HappySeolhyunDay
